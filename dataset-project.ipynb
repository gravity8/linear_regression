# %% [markdown]
# # dataset-project
#
# Use the "Run" button to execute the code.

# %%
# !pip install jovian --upgrade --quiet
# !pip install sklearn
# !pip install openpyxl

# %%
import jovian

# %%
# Execute this to save new versions of the notebook
jovian.commit(project="dataset-project")

# %% [markdown]
# # INTRODUCTION TO SUPERVISED LEARNING
# ## LINEAR REGRESSION
# ## IMPORT OF LIBRARIES THAT ARE NECESSARY FOR PROJECT

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn
import sklearn 
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### STEP#2 LOADING THE DATASET

# %%
df = pd.read_excel("AI_Invasion_In-Class_Dataset 2.xlsx")

# %%
df
# Out:
#      Location          Maker           Model    Year  Colour  \
# 0       Abuja  Mercedes-Benz         GLA 250  2015.0   Brown
# 1       Abuja        Hyundai          Accent  2013.0     Red
# 2       Lagos          Lexus  GX 460 Premium  2011.0   White
# 3       Lagos          Lexus          ES 350  2011.0    Gray
# 4      Ibadan         Toyota       Verso 1.6  2009.0  Silver
# ...       ...            ...             ...     ...     ...
# 4482    Lagos          Lexus          RX 330  2006.0    Blue
# 4483    Lagos          Lexus          ES 350  2007.0    Blue
# 4484    Abuja  Mercedes-Benz            E350  2014.0   Green
# 4485    Lagos          Lexus   GX 460 Luxury  2020.0   Black
# 4486    Lagos          Lexus     RX 450H AWD  2015.0  Silver
#
#       Amount (Million ₦)           Type  Distance_Km
# 0                  14.50   Foreign Used      50000.0
# 1                   1.55  Nigerian Used          NaN
# 2                  14.00   Foreign Used      85000.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4487 entries, 0 to 4486
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Location            4487 non-null   object
#  1   Maker               4487 non-null   object
#  2   Model               4487 non-null   object
#  3   Year                4487 non-null   float64
#  4   Colour              4487 non-null   object
#  5   Amount (Million ₦)  4487 non-null   float64
#  6   Type                4487 non-null   object
#  7   Distance_Km         2932 non-null   float64
# dtypes: float64(3), object(5)
# memory usage: 280.6+ KB

# %%
df.describe()
# Out:
#               Year  Amount (Million ₦)   Distance_Km
# count  4487.000000         4487.000000  2.932000e+03
# mean   2011.095610           11.309795  1.010383e+05
# std       4.823362           20.585915  1.150914e+05
# min    1982.000000            0.420000  1.000000e+00
# 25%    2008.000000            3.600000  5.237850e+04
# 50%    2011.000000            5.700000  7.900000e+04
# 75%    2014.000000           12.000000  1.099392e+05
# max    2022.000000          454.000000  1.785448e+06

# %% [markdown]
# ### STEP#3 CLEAN THE DATASET

# %%
df.columns
# Out:
# Index(['Location', 'Maker', 'Model', 'Year', 'Colour', 'Amount (Million ₦)',
#        'Type', 'Distance_Km'],
#       dtype='object')

# %%
#check for missing value
df.isnull().sum()
# Out:
# Location                 0
# Maker                    0
# Model                    0
# Year                     0
# Colour                   0
# Amount (Million ₦)       0
# Type                     0
# Distance_Km           1555
# dtype: int64

# %%
mean_value= df["Distance_Km"].mean()
print(mean_value)
df["Distance_Km"].fillna(mean_value,inplace=True)
# Out:
# 101038.32128240108

# %%
#re check for missing value
df.isnull().sum()
# Out:
# Location              0
# Maker                 0
# Model                 0
# Year                  0
# Colour                0
# Amount (Million ₦)    0
# Type                  0
# Distance_Km           0
# dtype: int64

# %%
cat_features={
    "Location",
    "Model",
    "Maker",
    "Year",
    "Colour",
    "Type"
}
for car_feature in car_features:
    print(car_feature, df[car_feature].unique(), sep=":")
    print ("#"* 50)
# Out:
# Model:['GLA 250' 'Accent' 'GX 460 Premium' 'ES 350' 'Verso 1.6' 'Corolla 1.8 LE'
#  'E350' 'GL-Class' 'RX 350 AWD' 'Land Cruiser 3.5 V6' 'Matrix'
#  'Land Cruiser' 'C350' 'Corolla' 'IS 250 4WD' 'Venza V6' 'CX-7' 'RX 350'
#  'Highlander Limited 4x4' 'RX' 'RX 350 F Sport AWD' 'Camry'
#  'Land Cruiser 5.7 V8 VX-S' 'GLK-Class' 'Avalon' 'GS 300' 'Accord'
#  '4-Runner' 'Civic' 'ES 330 Sedan' 'Corolla LE (1.8L 4cyl 2A)' 'Santa Fe'
#  'Highlander' 'Elantra' '4-Runner Limited V6' 'Venza Limited FWD V6'
#  'M Class ML 350 4Matic' 'M Class' 'Hyundai Kona' 'C300'
#  'Camry XLE V6 FWD' 'Range Rover Velar' 'IS 250' 'Highlander Limited'
#  'RAV4 Limited FWD' 'Cayenne' 'RX 330' 'RDX' 'Corolla XSE (1.8L 4cyl 2A)'
#  'Micra' 'Vibe 2.4L' 'Tacoma TRD Sport' 'Focus 1.8 TDDi Viva' 'GX 460'
#  'RAV4 Limited V6 4x4' 'Commander Limited 4x4' 'Tundra' 'Sonata' 'RAV4'
#  'F-150' 'GX' 'GS 300 Automatic' 'Sienna' 'Altima' 'Hyundai Ioniq'
#  'Tacoma' 'CLA-Class' 'Venza V6 AWD' 'MDX SUV 4dr AWD (3.7 6cyl 5A)'
# ...

# %%
#Drop the model features
df.drop("Model", axis=1, inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_41/3946706566.py in <module>
#       1 #Drop the model features
# ----> 2 df.drop("Model", axis=1, inplace=True)
#       3 df.head()
#
# /opt/conda/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
df
# Out:
#      Location          Maker    Year  Colour  Amount (Million ₦)  \
# 0       Abuja  Mercedes-Benz  2015.0   Brown               14.50
# 1       Abuja        Hyundai  2013.0     Red                1.55
# 2       Lagos          Lexus  2011.0   White               14.00
# 3       Lagos          Lexus  2011.0    Gray                4.95
# 4      Ibadan         Toyota  2009.0  Silver                1.69
# ...       ...            ...     ...     ...                 ...
# 4482    Lagos          Lexus  2006.0    Blue                4.60
# 4483    Lagos          Lexus  2007.0    Blue                4.50
# 4484    Abuja  Mercedes-Benz  2014.0   Green               10.45
# 4485    Lagos          Lexus  2020.0   Black               31.00
# 4486    Lagos          Lexus  2015.0  Silver               14.00
#
#                Type    Distance_Km
# 0      Foreign Used   50000.000000
# 1     Nigerian Used  101038.321282
# 2      Foreign Used   85000.000000
# 3      Foreign Used  101038.321282
# ...

# %%
#label Encoding
car_features = ["Location","Maker","Year","Colour","Type"]
for car_feature in car_features:
    df[f"{car_feature}_car"]=df[car_feature].astype('category')
    df[f"{car_feature}_car"]=df[f"{car_feature}_car"].cat.codes
    
    df.head()

# %%
df
# Out:
#      Location          Maker    Year  Colour  Amount (Million ₦)  \
# 0       Abuja  Mercedes-Benz  2015.0   Brown               14.50
# 1       Abuja        Hyundai  2013.0     Red                1.55
# 2       Lagos          Lexus  2011.0   White               14.00
# 3       Lagos          Lexus  2011.0    Gray                4.95
# 4      Ibadan         Toyota  2009.0  Silver                1.69
# ...       ...            ...     ...     ...                 ...
# 4482    Lagos          Lexus  2006.0    Blue                4.60
# 4483    Lagos          Lexus  2007.0    Blue                4.50
# 4484    Abuja  Mercedes-Benz  2014.0   Green               10.45
# 4485    Lagos          Lexus  2020.0   Black               31.00
# 4486    Lagos          Lexus  2015.0  Silver               14.00
#
#                Type    Distance_Km  Location_car  Maker_car  Year_car  \
# 0      Foreign Used   50000.000000             0         26        22
# ...
